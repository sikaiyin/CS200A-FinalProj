# %% [markdown]
# <h1> DS200A Computer Vision Assignment</h1>

# %% [markdown]
# <h2>  Part Two: Exploratory data analysis and feature extraction. </h2>

# %% [markdown]
# <h5> In this section, Compute at least 15 such image features (a method for each), including the following (NOTE: At least 10 of these must be scalar features and 2 matrix-based features): (i) image size, (ii) average of the red-channel intensity, (iii) aspectratio. This will require significant explatoratory research and data analysis. The first one is already implemented for you, and the next two are pre-specified. Additional requirements specfied in pdf. </h5>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import skimage
from skimage import data
from skimage import io
from skimage.feature import corner_harris, corner_shi_tomasi,corner_peaks
import os
# import cv2
import random
import seaborn as sns

#starting_data = pd.read_csv('data.csv',sep='\t')
starting_data = pd.read_hdf("data.h5", "starting_data")
starting_data.head()
# Out:
#                                             Pictures  Encoding
# 0  [[[255, 255, 255], [255, 255, 255], [255, 255,...         0
# 1  [[[255, 255, 255], [255, 255, 255], [255, 255,...         0
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...         0
# 3  [[[174, 190, 187], [173, 189, 186], [172, 188,...         0
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...         0

# %%
# below is Display three of the learning set images.

# %%
#Example of reading in a file


filename = os.path.join(os.getcwd(),"20_categories_training/20_categories_training/airplanes/airplanes_0001.jpg")
airplane1 = io.imread(filename)
skimage.io.imshow(airplane1)
plt.show()


filename2 = os.path.join(os.getcwd(),"20_categories_training/20_categories_training/killer-whale/killer-whale_0001.jpg")
killerwhale1 = io.imread(filename2)
skimage.io.imshow(killerwhale1)
plt.show()


filename3 = os.path.join(os.getcwd(),"20_categories_training/20_categories_training/zebra/zebra_0001.jpg")
zebra1 = io.imread(filename3)
skimage.io.imshow(zebra1)
plt.show()
# example_data_frame= pd.DataFrame()


# example_data_frame['Pictures']=[dog, cat]
# example_data_frame['Encoding']=[1,2]
# example_data_frame

# %%
# below is Provide graphical summaries of the sizes of the images, pixel intensities, and class frequencies

# %%
def rgb_conversion(image):
    if(len(image.shape) == 2):
        return skimage.color.gray2rgb(image)
    return image

# %%
starting_data["Pictures"] = starting_data["Pictures"].apply(rgb_conversion)

# %%
def imagesize(image):
    return image.size
imagesizeinfo = starting_data["Pictures"].apply(imagesize)

# %%
sns.distplot(imagesizeinfo,rug=True)
plt.xlim((0,10000000))
plt.xlabel('Image Size')
plt.title('Image Size Distribution');

# %%
def pixelintensityred(image):
    red=image[:,:,0].mean()
#     green=image[:,:,1].mean()
#     blue=image[:,:,2].mean()
    return red
def pixelintensitygreen(image):
#     red=image[:,:,0].mean()
    green=image[:,:,1].mean()
#     blue=image[:,:,2].mean()
    return green
def pixelintensityblue(image):
#     red=image[:,:,0].mean()
#     green=image[:,:,1].mean()
    blue=image[:,:,2].mean()
    return blue
#     df["mean_shi_tomasi"] = df["Pictures"].apply(ft14)
redinfo = starting_data["Pictures"].apply(pixelintensityred)
greeninfo = starting_data["Pictures"].apply(pixelintensitygreen)
blueinfo = starting_data["Pictures"].apply(pixelintensityblue)
# pixelintensityinfo

# %%
sns.distplot(redinfo,hist=False,label='red',color='r')
sns.distplot(greeninfo,hist=False,label='green',color='g')
sns.distplot(blueinfo,hist=False,label='blue',color='b')
plt.xlabel('Average Pixel Intensities')
plt.title('Pixel Intensity Distribution');

# %%
# for i in range(20):
count = starting_data.groupby(starting_data["Encoding"]).count()
count /= count.sum()
count=count.reset_index()

# %%
classes = ['airplanes', 'bear', 'blimp', 'comet', 'crab', 'dog', 'dolphin', 'giraffe', 'goat', 'gorilla', 'kangaroo', 'killer-whale', 'leopards', 'llama', 'penguin', 'porcupine', 'teddy-bear', 'triceratops', 'unicorn', 'zebra']
graph=sns.barplot(x='Encoding',y='Pictures',data=count)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Class Frequencies")
plt.title("Barplot for Class Frequencies");

# %%
sns.distplot(count['Pictures'])
plt.xlabel("Class Frequencies")
plt.title("Histogram for Class Frequencies");

# %%
# below is Provide functions that summarize pixel intensity data.

# %%
def ft0(image):
    return image.size
# Returns the pixel size of the image

def ft1(image):
    return image[:, :, 0].mean()
# Returns the average of the red-channel pictures for the images
def ft2(image):
    return image[:, :, 1].mean()
# Returns the average of the green-channel pictures for the images
def ft3(image):
    return image[:, :, 2].mean()
# Returns the average of the blue-channel pictures for the images

def ft4(image):
    return image[:, :, 0].std()
# Returns the std of the red-channel pictures for the images
def ft5(image):
    return image[:, :, 1].std()
# Returns the std of the green-channel pictures for the images
def ft6(image):
    return image[:, :, 2].std()
# Returns the std of the blue-channel pictures for the images

def ft7(image):
    return image.shape[0] / image.shape[1]
#Returns the aspect ratio of the image

def ft8(image):
    return skimage.color.rgb2hsv(image)[:, :, 0].mean()
# Returns the average of the Hue pictures for the images
def ft9(image):
    return skimage.color.rgb2hsv(image)[:, :, 1].mean()
# Returns the average of the Saturation pictures for the images
def ft10(image):
    return skimage.color.rgb2hsv(image)[:, :, 2].mean()
# Returns the average of the Value pictures for the images

def ft11(image):
    return skimage.color.rgb2hsv(image)[:, :, 0].std()
# Returns the std of the Hue pictures for the images
def ft12(image):
    return skimage.color.rgb2hsv(image)[:, :, 1].std()
# Returns the std of the Saturation pictures for the images
def ft13(image):
    return skimage.color.rgb2hsv(image)[:, :, 2].std()
# Returns the std of the Value pictures for the images

def ft14(image):
    grayscale = skimage.color.rgb2gray(image)
    return np.array(corner_peaks(corner_shi_tomasi(grayscale))).mean()
# Returns the average of Shi Tomasi edges for the images
def ft15(image):
    grayscale = skimage.color.rgb2gray(image)
    return np.array(corner_peaks(corner_shi_tomasi(grayscale))).std()
# Returns the std of Shi Tomasi edges for the images

# def ft16(image):
#     grayscale = skimage.color.rgb2gray(image)
#     return np.array(corner_peaks(corner_harris(grayscale))).mean()
# # Returns the average of Harris features for the images
# def ft17(image):
#     grayscale = skimage.color.rgb2gray(image)
#     return np.array(corner_peaks(corner_harris(grayscale))).std()
# # Returns the std of Harris features for the images

def ft18(image):
    return skimage.feature.hog(image, visualize = False,feature_vector=True).mean()
# Returns the average of HOG flattened vector for the images
def ft19(image):
    return skimage.feature.hog(image, visualize = False,feature_vector=True).std()
# Returns the std of HOG flattened vector for the images

def ft_hog(image):
    image = skimage.color.rgb2gray(image)
    image = skimage.transform.resize(image, (64, 64), mode='reflect')
    ppc = 32
    fd = skimage.feature.hog(image, orientations=9, pixels_per_cell=(ppc, ppc), 
                        cells_per_block=(2, 2), block_norm= 'L2', visualize=False)
    return fd

def ft_lbp(image):
    image = skimage.color.rgb2gray(image)
    image = skimage.transform.resize(image, (64, 64), mode='reflect')
    radius = 3
    n_points = 8 * radius
    lbp = skimage.feature.local_binary_pattern(image, n_points, radius, 'uniform')
    n_bins = int(lbp.max() + 1)
    hist, _ = np.histogram(lbp, density=True, bins=n_bins, range=(0, n_bins))
    return hist

# %% [markdown]
#  We expect all external sources sited, and significant indication of EDA.

# %%
# plt.figure(figsize = (16,8))
# for i in random.choices(starting_data['Encoding'].unique(),k=5):
#     sns.distplot((starting_data[starting_data['Encoding'] == i].apply(lambda x: ft0(x[0]), axis = 1)), hist = False)

# %%
# plt.figure(figsize = (16,8))
# for i in random.choices(starting_data['Encoding'].unique(),k=5):
#     sns.distplot((starting_data[starting_data['Encoding'] == i].apply(lambda x: ft1(x[0]), axis = 1)), hist = False)

# %%
# plt.figure(figsize = (16,8))
# for i in random.choices(starting_data['Encoding'].unique(),k=20):
#     sns.distplot((starting_data[starting_data['Encoding'] == i].apply(lambda x: ft7(x[0]), axis = 1)), hist = False)

# %% [markdown]
# <h4> Sources </h4>

# %%
'''
https://scikit-image.org/docs/dev/api/skimage.color.html
https://scikit-image.org/docs/dev/api/skimage.feature.html
https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_feature2d/py_features_meaning/py_features_meaning.html#features-meaning
'''
# Out:
# '\nhttps://scikit-image.org/docs/dev/api/skimage.color.html\nhttps://scikit-image.org/docs/dev/api/skimage.feature.html\nhttps://docs.opencv.org/3.0-beta/doc/py_tutorials/py_feature2d/py_features_meaning/py_features_meaning.html#features-meaning\n'

# %% [markdown]
# <h4> DataFrame Creation </h4>

# %%
def feature_frame(df):
    df["size"] = df["Pictures"].apply(ft0)
    df["mean_red"] = df["Pictures"].apply(ft1)
    df["mean_green"] = df["Pictures"].apply(ft2)
    df["mean_blue"] = df["Pictures"].apply(ft3)
    df["std_red"] = df["Pictures"].apply(ft4)
    df["std_green"] = df["Pictures"].apply(ft5)
    df["std_blue"] = df["Pictures"].apply(ft6)
    df["aspect_ratio"] = df["Pictures"].apply(ft7)
    df["mean_hue"] = df["Pictures"].apply(ft8)
    df["mean_sat"] = df["Pictures"].apply(ft9)
    df["mean_val"] = df["Pictures"].apply(ft10)
    df["std_hue"] = df["Pictures"].apply(ft11)
    df["std_sat"] = df["Pictures"].apply(ft12)
    df["std_val"] = df["Pictures"].apply(ft13)
    df["mean_shi_tomasi"] = df["Pictures"].apply(ft14)
    df["std_shi_tomasi"] = df["Pictures"].apply(ft15)
  #  df["mean_harris"] = df["Pictures"].apply(ft16)
  #  df["std_harris"] = df["Pictures"].apply(ft17)
    df["mean_hog"] = df["Pictures"].apply(ft18)
    df["std_hog"] = df["Pictures"].apply(ft19)
#     df["new_hog"]=df["Pictures"].apply(ft_hog)
#     df["lbp"]=df["Pictures"].apply(ft_lbp)
    del df["Pictures"]
    return df
    #Returns data-frame with all the features now inside, and calculated

# %%
def add_feature_frame(df):
    df_new=pd.DataFrame()
    df_new["new_hog"]=df["Pictures"].apply(ft_hog)
    df_new["lbp"]=df["Pictures"].apply(ft_lbp)
    return df_new

# %%
add_feature_df=add_feature_frame(starting_data)

# %%
add_feature_df.head()
# Out:
#                                              new_hog  \
# 0  [0.18233771014621677, 0.05018240737408546, 0.0...
# 1  [0.38652680915413096, 0.08038687983478697, 0.0...
# 2  [0.2904131712769664, 0.08498561077853249, 0.09...
# 3  [0.1269237572133359, 0.14364626559602134, 0.12...
# 4  [0.2210732821282576, 0.08045508838398106, 0.11...
#
#                                                  lbp
# 0  [0.0322265625, 0.03369140625, 0.021240234375, ...
# 1  [0.020751953125, 0.0166015625, 0.017822265625,...
# 2  [0.024658203125, 0.018798828125, 0.02197265625...
# 3  [0.057861328125, 0.033935546875, 0.029296875, ...
# 4  [0.041259765625, 0.0380859375, 0.03173828125, ...

# %%
spread_feature_df=pd.DataFrame()

# %%
for i in range(add_feature_df.shape[0]):
    for j in range(len(add_feature_df["new_hog"].iloc[i])):
        spread_feature_df.loc[i,"new_hog"+str(j)]=add_feature_df["new_hog"].iloc[i][j]
# spread_feature_df.head()
# Out:
#    new_hog0  new_hog1  new_hog2  new_hog3  new_hog4  new_hog5  new_hog6  \
# 0  0.182338  0.050182  0.052517  0.053317  0.080138  0.045149  0.066220
# 1  0.386527  0.080387  0.054529  0.085441  0.123205  0.109819  0.099515
# 2  0.290413  0.084986  0.091099  0.129430  0.119766  0.057620  0.065554
# 3  0.126924  0.143646  0.124522  0.117971  0.478144  0.130363  0.079257
# 4  0.221073  0.080455  0.118570  0.176742  0.356617  0.208189  0.222135
#
#    new_hog7  new_hog8  new_hog9  ...  new_hog26  new_hog27  new_hog28  \
# 0  0.056730  0.195927  0.161622  ...   0.206421   0.204132   0.049523
# 1  0.122461  0.374185  0.168127  ...   0.104060   0.263313   0.187584
# 2  0.033252  0.365659  0.230368  ...   0.171366   0.249247   0.110357
# 3  0.104958  0.095323  0.290031  ...   0.111591   0.189544   0.059850
# 4  0.119887  0.215747  0.140980  ...   0.179062   0.159105   0.044515
#
#    new_hog29  new_hog30  new_hog31  new_hog32  new_hog33  new_hog34  new_hog35
# ...

# %%
for i in range(add_feature_df.shape[0]):
    for j in range(len(add_feature_df["lbp"].iloc[i])):
        spread_feature_df.loc[i,"lbp"+str(j)]=add_feature_df["lbp"].iloc[i][j]
spread_feature_df.head()
# Out:
#    new_hog0  new_hog1  new_hog2  new_hog3  new_hog4  new_hog5  new_hog6  \
# 0  0.182338  0.050182  0.052517  0.053317  0.080138  0.045149  0.066220
# 1  0.386527  0.080387  0.054529  0.085441  0.123205  0.109819  0.099515
# 2  0.290413  0.084986  0.091099  0.129430  0.119766  0.057620  0.065554
# 3  0.126924  0.143646  0.124522  0.117971  0.478144  0.130363  0.079257
# 4  0.221073  0.080455  0.118570  0.176742  0.356617  0.208189  0.222135
#
#    new_hog7  new_hog8  new_hog9  ...     lbp16     lbp17     lbp18     lbp19  \
# 0  0.056730  0.195927  0.161622  ...  0.015381  0.019775  0.015137  0.014648
# 1  0.122461  0.374185  0.168127  ...  0.016846  0.015137  0.013184  0.010498
# 2  0.033252  0.365659  0.230368  ...  0.016357  0.011963  0.010254  0.011475
# 3  0.104958  0.095323  0.290031  ...  0.011475  0.010986  0.009766  0.009033
# 4  0.119887  0.215747  0.140980  ...  0.017090  0.018555  0.012695  0.013916
#
#       lbp20     lbp21     lbp22     lbp23     lbp24     lbp25
# ...

# %%
feature_df = feature_frame(starting_data)

# %%
feature_df.head()
# Out:
#    Encoding    size    mean_red  mean_green   mean_blue    std_red  std_green  \
# 0         0  195816  183.355727  176.750337  149.151581  56.406650  64.039966
# 1         0  221352  210.739822  189.280101  164.805242  55.293247  74.486619
# 2         0  194535  170.123787  147.788681  111.753798  64.391428  68.085443
# 3         0  200430  152.159752  132.648316   77.917303  64.525514  62.769907
# 4         0  208560  147.397886  150.504790   86.252963  73.855439  71.385855
#
#     std_blue  aspect_ratio  mean_hue  mean_sat  mean_val   std_hue   std_sat  \
# 0  79.648356      0.412060  0.218779  0.280749  0.738654  0.164833  0.272438
# 1  70.417988      0.458853  0.132492  0.271479  0.826690  0.146818  0.266601
# 2  89.914294      0.419847  0.234342  0.472204  0.700320  0.251214  0.357782
# 3  83.412773      0.432570  0.136092  0.555012  0.602172  0.125880  0.351580
# 4  94.391311      0.445570  0.213125  0.551104  0.613783  0.182543  0.359155
#
# ...

# %% [markdown]
# <h4> Graphs </h4>

# %%
# below is Examine how these image features vary between classes.

# %%
graph=sns.boxplot(y="size", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Size")
plt.ylim(0,1.5e6)
plt.title("Image Size Distribution of Each Class");

# %%
graph=sns.boxplot(y="mean_red", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Mean Red Channel Intensity")
plt.title("Mean Red Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="mean_green", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Mean Green Channel Intensity")
plt.title("Mean Green Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="mean_blue", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Mean Blue Channel Intensity")
plt.title("Mean Blue Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_red", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std Red Channel Intensity")
plt.title("Std Red Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_green", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std Green Channel Intensity")
plt.title("Std Green Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_blue", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std Blue Channel Intensity")
plt.title("Std Blue Channel Intensity Distribution of Each Class");

# %%
graph=sns.boxplot(y="aspect_ratio", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Aspect Ratio")
plt.title("Aspect Ratio Distribution of Each Class");

# %%
graph=sns.boxplot(y="mean_hue", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Average of the Hue Pictures")
plt.title("Average of the Hue Pictures Distribution of Each Class");

# %%
ax = sns.boxplot(y="mean_sat", x="Encoding", data=feature_df)
ax.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Average of the Saturation Pictures")
plt.title("Average of the Saturation Pictures Distribution of Each Class");

# %%
gragh=sns.boxplot(y="mean_val", x="Encoding", data=feature_df)
gragh.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Average of the Value Pictures")
plt.title("Average of the Value Pictures Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_hue", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std of the Hue Pictures")
plt.title("Std of the Hue Pictures Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_sat", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std of the Saturation Pictures")
plt.title("Std of the Saturation Pictures Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_val", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std of the Value Pictures")
plt.title("Std of the Value Pictures Distribution of Each Class");

# %%
graph=sns.boxplot(y="mean_shi_tomasi", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Average of Shi Tomasi Edges")
plt.ylim(0,500)
plt.title("Average of Shi Tomasi Edges Distribution of Each Class");

# %%
graph=sns.boxplot(y="std_shi_tomasi", x="Encoding", data=feature_df)
graph.set_xticklabels(labels=classes, rotation=90)
plt.xlabel("Class Encoding")
plt.ylabel("Std of Shi Tomasi Edges")
plt.ylim(0,250)
plt.title("Std of Shi Tomasi Edges Distribution of Each Class");

# %%
# below is creating matrix features and then concat them into the feature dataframe

# %%
feature_df=feature_df.reset_index()
# feature_df.drop(['level_0'])
# spread_feature_df=spread_feature_df.drop(['level_0'],axis=1)
spread_feature_df=spread_feature_df.reset_index()

# %%
spread_feature_df.head()
# Out:
#    index  new_hog0  new_hog1  new_hog2  new_hog3  new_hog4  new_hog5  \
# 0      0  0.182338  0.050182  0.052517  0.053317  0.080138  0.045149
# 1      1  0.386527  0.080387  0.054529  0.085441  0.123205  0.109819
# 2      2  0.290413  0.084986  0.091099  0.129430  0.119766  0.057620
# 3      3  0.126924  0.143646  0.124522  0.117971  0.478144  0.130363
# 4      4  0.221073  0.080455  0.118570  0.176742  0.356617  0.208189
#
#    new_hog6  new_hog7  new_hog8  ...     lbp16     lbp17     lbp18     lbp19  \
# 0  0.066220  0.056730  0.195927  ...  0.015381  0.019775  0.015137  0.014648
# 1  0.099515  0.122461  0.374185  ...  0.016846  0.015137  0.013184  0.010498
# 2  0.065554  0.033252  0.365659  ...  0.016357  0.011963  0.010254  0.011475
# 3  0.079257  0.104958  0.095323  ...  0.011475  0.010986  0.009766  0.009033
# 4  0.222135  0.119887  0.215747  ...  0.017090  0.018555  0.012695  0.013916
#
#       lbp20     lbp21     lbp22     lbp23     lbp24     lbp25
# ...

# %%
feature_df.head()
# Out:
#    index  Encoding    size    mean_red  mean_green   mean_blue    std_red  \
# 0      0         0  195816  183.355727  176.750337  149.151581  56.406650
# 1      1         0  221352  210.739822  189.280101  164.805242  55.293247
# 2      2         0  194535  170.123787  147.788681  111.753798  64.391428
# 3      3         0  200430  152.159752  132.648316   77.917303  64.525514
# 4      4         0  208560  147.397886  150.504790   86.252963  73.855439
#
#    std_green   std_blue  aspect_ratio  mean_hue  mean_sat  mean_val   std_hue  \
# 0  64.039966  79.648356      0.412060  0.218779  0.280749  0.738654  0.164833
# 1  74.486619  70.417988      0.458853  0.132492  0.271479  0.826690  0.146818
# 2  68.085443  89.914294      0.419847  0.234342  0.472204  0.700320  0.251214
# 3  62.769907  83.412773      0.432570  0.136092  0.555012  0.602172  0.125880
# 4  71.385855  94.391311      0.445570  0.213125  0.551104  0.613783  0.182543
#
# ...

# %%
concat_feature_df=pd.DataFrame()

# %%
concat_feature_df=pd.concat([feature_df,spread_feature_df],axis=1)

# %%
concat_feature_df.head()
# Out:
#    index  Encoding    size    mean_red  mean_green   mean_blue    std_red  \
# 0      0         0  195816  183.355727  176.750337  149.151581  56.406650
# 1      1         0  221352  210.739822  189.280101  164.805242  55.293247
# 2      2         0  194535  170.123787  147.788681  111.753798  64.391428
# 3      3         0  200430  152.159752  132.648316   77.917303  64.525514
# 4      4         0  208560  147.397886  150.504790   86.252963  73.855439
#
#    std_green   std_blue  aspect_ratio  ...     lbp16     lbp17     lbp18  \
# 0  64.039966  79.648356      0.412060  ...  0.015381  0.019775  0.015137
# 1  74.486619  70.417988      0.458853  ...  0.016846  0.015137  0.013184
# 2  68.085443  89.914294      0.419847  ...  0.016357  0.011963  0.010254
# 3  62.769907  83.412773      0.432570  ...  0.011475  0.010986  0.009766
# 4  71.385855  94.391311      0.445570  ...  0.017090  0.018555  0.012695
#
#       lbp19     lbp20     lbp21     lbp22     lbp23     lbp24     lbp25
# ...

# %%
concat_feature_df=concat_feature_df.drop(['index'],axis=1)

# %%
concat_feature_df.head()
# Out:
#    Encoding    size    mean_red  mean_green   mean_blue    std_red  std_green  \
# 0         0  195816  183.355727  176.750337  149.151581  56.406650  64.039966
# 1         0  221352  210.739822  189.280101  164.805242  55.293247  74.486619
# 2         0  194535  170.123787  147.788681  111.753798  64.391428  68.085443
# 3         0  200430  152.159752  132.648316   77.917303  64.525514  62.769907
# 4         0  208560  147.397886  150.504790   86.252963  73.855439  71.385855
#
#     std_blue  aspect_ratio  mean_hue  ...     lbp16     lbp17     lbp18  \
# 0  79.648356      0.412060  0.218779  ...  0.015381  0.019775  0.015137
# 1  70.417988      0.458853  0.132492  ...  0.016846  0.015137  0.013184
# 2  89.914294      0.419847  0.234342  ...  0.016357  0.011963  0.010254
# 3  83.412773      0.432570  0.136092  ...  0.011475  0.010986  0.009766
# 4  94.391311      0.445570  0.213125  ...  0.017090  0.018555  0.012695
#
# ...

# %%
concat_feature_df.to_hdf("concat_feature.h5", "concat_feature", mode="w")

# %%
# below is EDA for test data

# %%
starting_data_test = pd.read_hdf("data_test.h5", "starting_data_test")

# %%
starting_data_test["Pictures"] = starting_data_test["Pictures"].apply(rgb_conversion)

# %%
starting_data_test.head()
# Out:
#                                             Pictures
# 0  [[[80, 79, 74], [56, 55, 50], [54, 53, 48], [4...
# 1  [[[10, 15, 19], [10, 15, 19], [11, 16, 19], [1...
# 2  [[[232, 231, 247], [250, 249, 255], [235, 234,...
# 3  [[[97, 75, 77], [98, 76, 78], [99, 77, 79], [1...
# 4  [[[19, 46, 55], [19, 46, 53], [20, 47, 54], [2...

# %%
add_feature_df_test=add_feature_frame(starting_data_test)

# %%
spread_feature_df_test=pd.DataFrame()

# %%
for i in range(add_feature_df_test.shape[0]):
    for j in range(len(add_feature_df_test["new_hog"].iloc[i])):
        spread_feature_df_test.loc[i,"new_hog"+str(j)]=add_feature_df_test["new_hog"].iloc[i][j]

# %%
for i in range(add_feature_df_test.shape[0]):
    for j in range(len(add_feature_df_test["lbp"].iloc[i])):
        spread_feature_df_test.loc[i,"lbp"+str(j)]=add_feature_df_test["lbp"].iloc[i][j]

# %%
feature_df_test = feature_frame(starting_data_test)

# %%
feature_df_test=feature_df_test.reset_index()
# feature_df.head()
spread_feature_df_test=spread_feature_df_test.reset_index()

# %%
concat_feature_df_test=pd.concat([feature_df_test,spread_feature_df_test],axis=1)

# %%
concat_feature_df_test=concat_feature_df_test.drop(['index'],axis=1)

# %%
concat_feature_df_test.head()
# Out:
#       size    mean_red  mean_green   mean_blue    std_red  std_green  \
# 0  1620000  105.980433  106.905494  105.590887  67.205121  65.316848
# 1    91821  144.792694  147.593426  133.982324  79.839361  77.287288
# 2   312006  133.637670  123.831301  118.584796  68.821922  72.801423
# 3    70308   96.696962   83.622675   85.577701  61.854443  52.434449
# 4   244650   23.246266   40.598455   46.887554  25.818695  28.859210
#
#     std_blue  aspect_ratio  mean_hue  mean_sat  ...     lbp16     lbp17  \
# 0  63.113690      0.666667  0.409657  0.182231  ...  0.013184  0.014404
# 1  76.796918      0.526971  0.232295  0.167132  ...  0.011963  0.009766
# 2  82.262728      1.171141  0.256328  0.269049  ...  0.021973  0.018066
# 3  48.460702      0.656085  0.570737  0.185358  ...  0.016846  0.014648
# 4  34.166635      1.502146  0.530790  0.555373  ...  0.009521  0.008301
#
#       lbp18     lbp19     lbp20     lbp21     lbp22     lbp23     lbp24  \
# ...

# %%
concat_feature_df_test.to_hdf("concat_feature_test.h5", "concat_feature_test", mode="w")
