# %% [markdown]
# <h1> DS200A Computer Vision Assignment</h1>

# %% [markdown]
# <h2>  Part One: Data Input </h2>

# %% [markdown]
# <h3>  Import Statements </h3>

# %%
#Import anything you need here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import skimage
from skimage import data
from skimage import io
import pandas as pd
import os
import re

# %%
#Example of reading in a file
def show_img(path):
    img = io.imread(path)
    skimage.io.imshow(img)

show_img('20_categories_training/llama/llama_0002.jpg')

# %% [markdown]
# <h4> Using the code for reference, take the given folder and create a dataframe with the picture object, and the encoding as listed below. </h4>
# 0=Airplanes, 1=Bear, 2=Blimp, 3=Comet, 4=Crab, 5=Dog, 6=Dolphin, 7=Giraffe, 8=Goat, 9=Gorilla, 10=Kangaroo, 11=Killer-Whale, 12=Leopards, 13=Llama, 14= Penguin, 15= Porcupine, 16=Teddy-Bear, 17=Triceratops, 18=Unicorn, 19=Zebra

# %% [markdown]
# ### Define Load training & Validation Data Functions

# %%
encoding = {'airplanes':0, 'bear':1, 'blimp':2, 'comet':3, 'crab':4,\
            'dog':5, 'dolphin':6, 'giraffe':7, 'goat':8, 'gorilla':9,\
            'kangaroo':10, 'killer-whale':11, 'leopards':12, 'llama':13,\
            'penguin':14, 'porcupine':15, 'teddy-bear':16,'triceratops':17,\
            'unicorn':18, 'zebra':19}

def read_organize_data(file_path):
    img_df = pd.DataFrame(columns = ['Image','Picture','Encoding'])
    for dirpath, dirnames, filenames in os.walk(file_path):
        for file in filenames:
            img = io.imread(dirpath+'/'+file)
            row = {'Image':img,'Picture':file.split('_')[0],'Encoding':encoding[file.split('_')[0]]}
            img_df = img_df.append(row,ignore_index=True)
    return img_df

def order(filename):
    pattern = r'\d+'
    return int(re.findall(pattern,filename)[0])

def create_validation_data(file_path):
    img_df = pd.DataFrame(columns = ['Image'])
    for dirpath, dirnames, filenames in os.walk(file_path):
        for file in sorted(filenames, key=order):
            img = io.imread(dirpath+'/'+file)
            row = {'Image':img}
            img_df = img_df.append(row,ignore_index=True)
    return img_df

# %% [markdown]
# ##### Note: The code above does not directly work for Mac OS because Mac system has .DS_Store file, which must be deleted first

# %% [markdown]
# ### Store images in two dataframes

# %%
starting_data = read_organize_data("20_categories_training")
validation_data = create_validation_data("20_Validation")
# Out:
# validation_pic (1).jpg
# validation_pic (2).jpg
# validation_pic (3).jpg
# validation_pic (4).jpg
# validation_pic (5).jpg
# validation_pic (6).jpg
# validation_pic (7).jpg
# validation_pic (8).jpg
# validation_pic (9).jpg
# validation_pic (10).jpg
# validation_pic (11).jpg
# validation_pic (12).jpg
# validation_pic (13).jpg
# validation_pic (14).jpg
# validation_pic (15).jpg
# validation_pic (16).jpg
# validation_pic (17).jpg
# validation_pic (18).jpg
# validation_pic (19).jpg
# validation_pic (20).jpg
# validation_pic (21).jpg
# validation_pic (22).jpg
# validation_pic (23).jpg
# validation_pic (24).jpg
# validation_pic (25).jpg
# validation_pic (26).jpg
# validation_pic (27).jpg
# validation_pic (28).jpg
# validation_pic (29).jpg
# validation_pic (30).jpg
# validation_pic (31).jpg
# validation_pic (32).jpg
# validation_pic (33).jpg
# validation_pic (34).jpg
# validation_pic (35).jpg
# validation_pic (36).jpg
# validation_pic (37).jpg
# validation_pic (38).jpg
# ...

# %% [markdown]
# ### Data Store for transfering between notebooks

# %%
# %store starting_data
# %store validation_data
# Out:
# Stored 'starting_data' (DataFrame)
# Stored 'validation_data' (DataFrame)
